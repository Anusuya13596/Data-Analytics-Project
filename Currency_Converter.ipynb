# %%
def INRConverter(x):
  print("\na)Indian Rupee (INR) \nb)US Dollar (USD) \nc)Chinese Yuan (CNY) \nd)Japanese Yen (JPY) \ne)Egyptian Pound (EGP) \nf)Eur (EUR) \ng)Philippine Peso (PHP) \nh)Indonesian Rupiah (IDR) \ni)Kuwaiti Dinar (KWD) \nj)Swiss Franc (CHF) \nk)Israeli New Sheqel (ILS) \nl)Omani Rial (OMR) \nm)Aruban Florin (AWG) \nn)Singapore Dollar (SGD) \no)Bulgarian Lev (BGV)")
  cur2 = input(print("\nChoose anyone option for Currency Convert To :___________________"))
  if cur2=='o':
    awg1 = t * 1.01
    print("\nBulgarian Lev (BGV) value :",awg1)
print("\na)Indian Rupee (INR) \nb)US Dollar (USD) \nc)Chinese Yuan (CNY) \nd)Japanese Yen (JPY) \ne)Egyptian Pound (EGP) \nf)Eur (EUR) \ng)Philippine Peso (PHP) \nh)Indonesian Rupiah (IDR) \ni)Kuwaiti Dinar (KWD) \nj)Swiss Franc (CHF) \nk)Israeli New Sheqel (ILS) \nl)Omani Rial (OMR) \nm)Aruban Florin (AWG) \nn)Singapore Dollar (SGD) \no)Bulgarian Lev (BGV)")
cur1 = input(print("\nChoose anyone option for Currency Convert From :___________________"))
if cur1=='m':
 INRConverter(cur1)

# %%
a=float(input(print("Enter the INR vaalue:")))
b=0.013*a
print("The USD value :",b)
# Out:
# Enter the INR vaalue:
# 2
# The USD value : 0.026

# %%
#Sub Function2 - for conversion of value
#AWG Coversion
def awg2bgv(a1):
  awg1 = a1 * 1.01
  print("\nThe Bulgarian Lev (BGV) value :",awg1)
def awg2cny(a2):
  awg2 = a2 * 3.72
  print("\nThe Chinese Yuan (CNY) value :",awg2)
def awg2egp(a3):
  awg3 = a3 * 10.33
  print("\nThe Egyptian Pound (EGP) value :",awg3)
def awg2eur(a4):
  awg4 = a4 * 0.52
  print("\nThe Euro (EUR) value :",awg4)
def awg2inr(a5):
  awg5 = a5 * 43.15
  print("\nThe Indian Rupee (INR) value :",awg5)
def awg2idr(a6):
  awg6 = a6 * 8075.26
  print("\nThe Indonesian Rupiah (IDR) value :",awg6)
def awg2ils(a7):
  awg7 = a7 * 1.86
  print("\nThe Israeli New Shekel (ILS) value :",awg7)
def awg2jpy(a8):
  awg8 = a8 * 70.59
  print("\nThe Japanese Yen (JPY) value :",awg8)
def awg2kwd(a9):
  awg9 = a9 * 0.17
  print("\nThe Kuwaiti Dinar (KWD) value :",awg9)
def awg2omr(a10):
  awg10 = a10 * 0.21
  print("\nThe Omani Rial (OMR) value :",awg10)
def awg2php(a11):
  awg11 = a11 * 29.06
  print("\nThe Philippine Peso (PHP) value :",awg11)
def awg2sgd(a12):
  awg12 = a12 * 0.76
  print("\nThe Singapore Dollar (SGD) value :",awg12)
def awg2chf(a13):
  awg13 = a13 * 0.53
  print("\nThe Swiss Franc (CHF) value :",awg13)
def awg2usd(a14):
  awg14 = a14 * 0.56
  print("\nThe US Dollar (USD) value :",awg14)
#BGV Conversion
def bgv2awg(b1):
  bgv1 = b1 * 0.99
  print("\nThe Aruban Florin (AWG) value :",bgv1)
def bgv2cny(b2):
  bgv2 = b2 * 3.67
  print("\nThe Chinese Yuan (CNY) value :",bgv2)
def bgv2egp(b3):
  bgv3 = b3 * 10.18
  print("\nThe Egyptian Pound (EGP) value :",bgv3)
def bgv2eur(b4):
  bgv4 = b4 * 0.51
  print("\nThe Euro (EUR) value :",bgv4)
def bgv2inr(b5):
  bgv5 = b5 * 42.53
  print("\nThe Indian Rupee (INR) value :",bgv5)
def bgv2idr(b6):
  bgv6 = b6 * 7958.34
  print("\nThe Indonesian Rupiah (IDR) value :",bgv6)
def bgv2ils(b7):
  bgv7 = b7 * 1.83
  print("\nThe Israeli New Shekel (ILS) value :",bgv7)
def bgv2jpy(b8):
  bgv8 = b8 * 69.57
  print("\nThe Japanese Yen (JPY) value :",bgv8)
def bgv2kwd(b9):
  bgv9 = b9 * 0.17
  print("\nThe Kuwaiti Dinar (KWD) value :",bgv9)
def bgv2omr(b10):
  bgv10 = b10 * 0.21
  print("\nThe Omani Rial (OMR) value :",bgv10)
def bgv2php(b11):
  bgv11 = b11 * 28.64
  print("\nThe Philippine Peso (PHP) value :",bgv11)
def bgv2sgd(b12):
  bgv12 = b12 * 0.75
  print("\nThe Singapore Dollar (SGD) value :",bgv12)
def bgv2chf(b13):
  bgv13 = b13 * 0.52
  print("\nThe Swiss Franc (CHF) value :",bgv13)
def bgv2usd(b14):
  bgv14 = b14 * 0.55
  print("\nThe US Dollar (USD) value :",bgv14)
#CNY Conversion
def cny2awg(c1):
  cny1 = c1 * 0.27
  print("\nThe Aruban Florin (AWG) value :",cny1)
def cny2bgv(c2):
  cny2 = c2 * 0.27
  print("\nThe Bulgarian Lev (BGV) value :",cny2)
def cny2egp(c3):
  cny3 = c3 * 2.78
  print("\nThe Egyptian Pound (EGP) value :",cny3)
def cny2eur(c4):
  cny4 = c4 * 0.14
  print("\nThe Euro (EUR) value :",cny4)
def cny2inr(c5):
  cny5 = c5 * 11.6
  print("\nThe Indian Rupee (INR) value :",cny5)
def cny2idr(c6):
  cny6 = c6 * 2170.51
  print("\nThe Indonesian Rupiah (IDR) value :",cny6)
def cny2ils(c7):
  cny7 = c7 * 0.50
  print("\nThe Israeli New Shekel (ILS) value :",cny7)
def cny2jpy(c8):
  cny8 = c8 * 18.97
  print("\nThe Japanese Yen (JPY) value :",cny8)
def cny2kwd(c9):
  cny9 = c9 * 0.046
  print("\nThe Kuwaiti Dinar (KWD) value :",cny9)
def cny2omr(c10):
  cny10 = c10 * 0.057
  print("\nThe Omani Rial (OMR) value :",cny10)
def cny2php(c11):
  cny11 = c11 * 7.81
  print("\nThe Philippine Peso (PHP) value :",cny11)
def cny2sgd(c12):
  cny12 = c12 * 0.21
  print("\nThe Singapore Dollar (SGD) value :",cny12)
def cny2chf(c13):
  cny13 = c13 * 0.14
  print("\nThe Swiss Franc (CHF) value :",cny13)
def cny2usd(c14):
  cny14 = c14 * 0.15
  print("\nThe US Dollar (USD) value :",cny14)
#EGP Conversion
def egp2awg(d1):
  egp1 = d1 * 0.097
  print("\nThe Aruban Florin (AWG) value :",egp1)
def egp2bgv(d2):
  egp2 = d2 * 0.098
  print("\nThe Bulgarian Lev (BGV) value :",egp2)
def egp2cny(d3):
  egp3 = d3 * 0.36
  print("\nThe Chinese Yuan (CNY) value :",egp3)
def egp2eur(d4):
  egp4 = d4 * 0.05
  print("\nThe Euro (EUR) value :",egp4)
def egp2inr(d5):
  egp5 = d5 * 4.18
  print("\nThe Indian Rupee (INR) value :",egp5)
def egp2idr(d6):
  egp6 = d6 * 781.96
  print("\nThe Indonesian Rupiah (IDR) value :",egp6)
def egp2ils(d7):
  egp7 = d7 * 0.18
  print("\nThe Israeli New Shekel (ILS) value :",egp7)
def egp2jpy(d8):
  egp8 = d8 * 6.84
  print("\nThe Japanese Yen (JPY) value :",egp8)
def egp2kwd(d9):
  egp9 = d9 * 0.016
  print("\nThe Kuwaiti Dinar (KWD) value :",egp9)
def egp2omr(d10):
  egp10 = d10 * 0.021
  print("\nThe Omani Rial (OMR) value :",egp10)
def egp2php(d11):
  egp11 = d11 * 2.81
  print("\nThe Philippine Peso (PHP) value :",egp11)
def egp2sgd(d12):
  egp12 = d12 * 0.074
  print("\nThe Singapore Dollar (SGD) value :",egp12)
def egp2chf(d13):
  egp13 = d13 * 0.051
  print("\nThe Swiss Franc (CHF) value :",egp13)
def egp2usd(d14):
  egp14 = d14 * 0.054
  print("\nThe US Dollar (USD) value :",egp14)
#EUR Conversion
def eur2awg(e1):
  eur1 = e1 * 1.93
  print("\nThe Aruban Florin (AWG) value :",eur1)
def eur2bgv(e2):
  eur2 = e2 * 1.959
  print("\nThe Bulgarian Lev (BGV) value :",eur2)
def eur2cny(e3):
  eur3 = e3 * 7.193
  print("\nThe Chinese Yuan (CNY) value :",eur3)
def eur2egp(e4):
  eur4 = e4 * 19.953
  print("\nThe Egyptian Pound (EGP) value :",eur4)
def eur2inr(e5):
  eur5 = e5 * 83.301
  print("\nThe Indian Rupee (INR) value :",eur5)
def eur2idr(e6):
  eur6 = e6 * 15651.847
  print("\nThe Indonesian Rupiah (IDR) value :",eur6)
def eur2ils(e7):
  eur7 = e7 * 3.59
  print("\nThe Israeli New Shekel (ILS) value :",eur7)
def eur2jpy(e8):
  eur8 = e8 * 136.474
  print("\nThe Japanese Yen (JPY) value :",eur8)
def eur2kwd(e9):
  eur9 = e9 * 0.328
  print("\nThe Kuwaiti Dinar (KWD) value :",eur9)
def eur2omr(e10):
  eur10 = e10 * 0.413
  print("\nThe Omani Rial (OMR) value :",eur10)
def eur2php(e11):
  eur11 = e11 * 56.174 
  print("\nThe Philippine Peso (PHP) value :",eur11)
def eur2sgd(e12):
  eur12 = e12 * 1.47
  print("\nThe Singapore Dollar (SGD) value :",eur12)
def eur2chf(e13):
  eur13 = e13 * 1.028
  print("\nThe Swiss Franc (CHF) value :",eur13)
def eur2usd(e14):
  eur14 = e14 * 1.074
  print("\nThe US Dollar (USD) value :",eur14)
#INR Conversion
def inr2awg(f1):
  inr1 = f1 * 0.023
  print("\nThe Aruban Florin (AWG) value :",inr1)
def inr2bgv(f2):
  inr2 = f2 * 0.024
  print("\nThe Bulgarian Lev (BGV) value :",inr2)
def inr2cny(f3):
  inr3 = f3 * 0.086
  print("\nThe Chinese Yuan (CNY) value :",inr3)
def inr2egp(f4):
  inr4 = f4 * 0.24
  print("\nThe Egyptian Pound (EGP) value :",inr4)
def inr2eur(f5):
  inr5 = f5 * 0.012
  print("\nThe Euro (EUR) value :",inr5)
def inr2idr(f6):
  inr6 = f6 * 187.14
  print("\nThe Indonesian Rupiah (IDR) value :",inr6)
def inr2ils(f7):
  inr7 = f7 * 0.043
  print("\nThe Israeli New Shekel (ILS) value :",inr7)
def inr2jpy(f8):
  inr8 = f8 * 1.64
  print("\nThe Japanese Yen (JPY) value :",inr8)
def inr2kwd(f9):
  inr9 = f9 * 0.0039
  print("\nThe Kuwaiti Dinar (KWD) value :",inr9)
def inr2omr(f10):
  inr10 = f10 * 0.005
  print("\nThe Omani Rial (OMR) value :",inr10)
def inr2php(f11):
  inr11 = f11 * 0.67 
  print("\nThe Philippine Peso (PHP) value :",inr11)
def inr2sgd(f12):
  inr12 = f12 * 0.018
  print("\nThe Singapore Dollar (SGD) value :",inr12)
def inr2chf(f13):
  inr13 = f13 * 0.012
  print("\nThe Swiss Franc (CHF) value :",inr13)
def inr2usd(f14):
  inr14 = f14 * 0.013
  print("\nThe US Dollar (USD) value :",inr14)
#IDR Conversion
def idr2awg(g1):
  idr1 = g1 * 0.00012
  print("\nThe Aruban Florin (AWG) value :",idr1)
def idr2bgv(g2):
  idr2 = g2 * 0.00013
  print("\nThe Bulgarian Lev (BGV) value :",idr2)
def idr2cny(g3):
  idr3 = g3 * 0.00046
  print("\nThe Chinese Yuan (CNY) value :",idr3)
def idr2egp(g4):
  idr4 = g4 * 0.0013
  print("\nThe Egyptian Pound (EGP) value :",idr4)
def idr2eur(g5):
  idr5 = g5 * 0.000064
  print("\nThe Euro (EUR) value :",idr5)
def idr2inr(g6):
  idr6 = g6 * 0.0053
  print("\nThe Indian Rupee (INR) value :",idr6)
def idr2ils(g7):
  idr7 = g7 * 0.00023
  print("\nThe Israeli New Shekel (ILS) value :",idr7)
def idr2jpy(g8):
  idr8 = g8 * 0.0087
  print("\nThe Japanese Yen (JPY) value :",idr8)
def idr2kwd(g9):
  idr9 = g9 * 0.000021
  print("\nThe Kuwaiti Dinar (KWD) value :",idr9)
def idr2omr(g10):
  idr10 = g10 * 0.000026
  print("\nThe Omani Rial (OMR) value :",idr10)
def idr2php(g11):
  idr11 = g11 * 0.0036 
  print("\nThe Philippine Peso (PHP) value :",idr11)
def idr2sgd(g12):
  idr12 = g12 * 0.000094
  print("\nThe Singapore Dollar (SGD) value :",idr12)
def idr2chf(g13):
  idr13 = g13 * 0.000066
  print("\nThe Swiss Franc (CHF) value :",idr13)
def idr2usd(g14):
  idr14 = g14 * 0.000069
  print("\nThe US Dollar (USD) value :",idr14)
#ILS Conversion
def ils2awg(h1):
  ils1 = h1 * 0.54
  print("\nThe Aruban Florin (AWG) value :",ils1)
def ils2bgv(h2):
  ils2 = h2 * 0.55
  print("\nThe Bulgarian Lev (BGV) value :",ils2)
def ils2cny(h3):
  ils3 = h3 * 2.00
  print("\nThe Chinese Yuan (CNY) value :",ils3)
def ils2egp(h4):
  ils4 = h4 * 5.56
  print("\nThe Egyptian Pound (EGP) value :",ils4)
def ils2eur(h5):
  ils5 = h5 * 0.28
  print("\nThe Euro (EUR) value :",ils5)
def ils2inr(h6):
  ils6 = h6 * 23.23
  print("\nThe Indian Rupee (INR) value :",ils6)
def ils2idr(h7):
  ils7 = h7 * 4347.04
  print("\nThe Indonesian Rupiah (IDR) value :",ils7)
def ils2jpy(h8):
  ils8 = h8 * 38.00
  print("\nThe Japanese Yen (JPY) value :",ils8)
def ils2kwd(h9):
  ils9 = h9 * 0.091
  print("\nThe Kuwaiti Dinar (KWD) value :",ils9)
def ils2omr(h10):
  ils10 = h10 * 0.12
  print("\nThe Omani Rial (OMR) value :",ils10)
def ils2php(h11):
  ils11 = h11 * 15.64 
  print("\nThe Philippine Peso (PHP) value :",ils11)
def ils2sgd(h12):
  ils12 = h12 * 0.41
  print("\nThe Singapore Dollar (SGD) value :",ils12)
def ils2chf(h13):
  ils13 = h13 * 0.29
  print("\nThe Swiss Franc (CHF) value :",ils13)
def ils2usd(h14):
  ils14 = h14 * 0.3
  print("\nThe US Dollar (USD) value :",ils14)
#JPY Conversion
def jpy2awg(i1):
  jpy1 = i1 * 0.014
  print("\nThe Aruban Florin (AWG) value :",jpy1)
def jpy2bgv(i2):
  jpy2 = i2 * 0.014
  print("\nThe Bulgarian Lev (BGV) value :",jpy2)
def jpy2cny(i3):
  jpy3 = i3 * 0.053
  print("\nThe Chinese Yuan (CNY) value :",jpy3)
def jpy2egp(i4):
  jpy4 = i4 * 0.15
  print("\nThe Egyptian Pound (EGP) value :",jpy4)
def jpy2eur(i5):
  jpy5 = i5 * 0.0073
  print("\nThe Euro (EUR) value :",jpy5)
def jpy2inr(i6):
  jpy6 = i6 * 0.61
  print("\nThe Indian Rupee (INR) value :",jpy6)
def jpy2idr(i7):
  jpy7 = i7 * 114.36
  print("\nThe Indonesian Rupiah (IDR) value :",jpy7)
def jpy2ils(i8):
  jpy8 = i8 * 0.026
  print("\nThe Israeli New Shekel (ILS) value :",jpy8)
def jpy2kwd(i9):
  jpy9 = i9 * 0.0024
  print("\nThe Kuwaiti Dinar (KWD) value :",jpy9)
def jpy2omr(i10):
  jpy10 = i10 * 0.003
  print("\nThe Omani Rial (OMR) value :",jpy10)
def jpy2php(i11):
  jpy11 = i11 * 0.41 
  print("\nThe Philippine Peso (PHP) value :",jpy11)
def jpy2sgd(i12):
  jpy12 = i12 * 0.011
  print("\nThe Singapore Dollar (SGD) value :",jpy12)
def jpy2chf(i13):
  jpy13 = i13 * 0.0075
  print("\nThe Swiss Franc (CHF) value :",jpy13)
def jpy2usd(i14):
  jpy14 = i14 * 0.0079
  print("\nThe US Dollar (USD) value :",jpy14)
#KWD Conversion
def kwd2awg(j1):
  kwd1 = j1 * 5.89
  print("\nThe Aruban Florin (AWG) value :",kwd1)
def kwd2bgv(j2):
  kwd2 = j2 * 5.98
  print("\nThe Bulgarian Lev (BGV) value :",kwd2)
def kwd2cny(j3):
  kwd3 = j3 * 21.93
  print("\nThe Chinese Yuan (CNY) value :",kwd3)
def kwd2egp(j4):
  kwd4 = j4 * 60.86
  print("\nThe Egyptian Pound (EGP) value :",kwd4)
def kwd2eur(j5):
  kwd5 = j5 * 3.05
  print("\nThe Euro (EUR) value :",kwd5)
def kwd2inr(j6):
  kwd6 = j6 * 254.30
  print("\nThe Indian Rupee (INR) value :",kwd6)
def kwd2idr(j7):
  kwd7 = j7 * 47589.62
  print("\nThe Indonesian Rupiah (IDR) value :",kwd7)
def kwd2ils(j8):
  kwd8 = j8 * 10.95
  print("\nThe Israeli New Shekel (ILS) value :",kwd8)
def kwd2jpy(j9):
  kwd9 = j9 * 416.00
  print("\nThe Japanese Yen (JPY) value :",kwd9)
def kwd2omr(j10):
  kwd10 = j10 * 1.26
  print("\nThe Omani Rial (OMR) value :",kwd10)
def kwd2php(j11):
  kwd11 = j11 * 171.27 
  print("\nThe Philippine Peso (PHP) value :",kwd11)
def kwd2sgd(j12):
  kwd12 = j12 * 4.50
  print("\nThe Singapore Dollar (SGD) value :",kwd12)
def kwd2chf(j13):
  kwd13 = j13 * 3.13
  print("\nThe Swiss Franc (CHF) value :",kwd13)
def kwd2usd(j14):
  kwd14 = j14 * 3.27
  print("\nThe US Dollar (USD) value :",kwd14)
#OMR Conversion
def omr2awg(k1):
  omr1 = k1 * 4.68
  print("\nThe Aruban Florin (AWG) value :",omr1)
def omr2bgv(k2):
  omr2 = k2 * 4.75
  print("\nThe Bulgarian Lev (BGV) value :",omr2)
def omr2cny(k3):
  omr3 = k3 * 17.41
  print("\nThe Chinese Yuan (CNY) value :",omr3)
def omr2egp(k4):
  omr4 = k4 * 48.32
  print("\nThe Egyptian Pound (EGP) value :",omr4)
def omr2eur(k5):
  omr5 = k5 * 2.42
  print("\nThe Euro (EUR) value :",omr5)
def omr2inr(k6):
  omr6 = k6 * 201.92
  print("\nThe Indian Rupee (INR) value :",omr6)
def omr2idr(k7):
  omr7 = k7 * 37786.82
  print("\nThe Indonesian Rupiah (IDR) value :",omr7)
def omr2ils(k8):
  omr8 = k8 * 8.69
  print("\nThe Israeli New Shekel (ILS) value :",omr8)
def omr2jpy(k9):
  omr9 = k9 * 330.31
  print("\nThe Japanese Yen (JPY) value :",omr9)
def omr2kwd(k10):
  omr10 = k10 * 0.79
  print("\nThe Kuwaiti Dinar (KWD) value :",omr10)
def omr2php(k11):
  omr11 = k11 * 135.99 
  print("\nThe Philippine Peso (PHP) value :",omr11)
def omr2sgd(k12):
  omr12 = k12 * 3.57
  print("\nThe Singapore Dollar (SGD) value :",omr12)
def omr2chf(k13):
  omr13 = k13 * 2.49
  print("\nThe Swiss Franc (CHF) value :",omr13)
def omr2usd(k14):
  omr14 = k14 * 2.60
  print("\nThe US Dollar (USD) value :",omr14)
#PHP Conversion
def php2awg(l1):
  php1 = l1 * 0.034
  print("\nThe Aruban Florin (AWG) value :",php1)
def php2bgv(l2):
  php2 = l2 * 0.035
  print("\nThe Bulgarian Lev (BGV) value :",php2)
def php2cny(l3):
  php3 = l3 * 0.13
  print("\nThe Chinese Yuan (CNY) value :",php3)
def php2egp(l4):
  php4 = l4 * 0.36
  print("\nThe Egyptian Pound (EGP) value :",php4)
def php2eur(l5):
  php5 = l5 * 0.018
  print("\nThe Euro (EUR) value :",php5)
def php2inr(l6):
  php6 = l6 * 1.48
  print("\nThe Indian Rupee (INR) value :",php6)
def php2idr(l7):
  php7 = l7 * 277.87
  print("\nThe Indonesian Rupiah (IDR) value :",php7)
def php2ils(l8):
  php8 = l8 * 0.064
  print("\nThe Israeli New Shekel (ILS) value :",php8)
def php2jpy(l9):
  php9 = l9 * 2.43
  print("\nThe Japanese Yen (JPY) value :",php9)
def php2kwd(l10):
  php10 = l10 * 0.0058
  print("\nThe Kuwaiti Dinar (KWD) value :",php10)
def php2omr(l11):
  php11 = l11 * 0.0074 
  print("\nThe Omani Rial (OMR) value :",php11)
def php2sgd(l12):
  php12 = l12 * 0.026
  print("\nThe Singapore Dollar (SGD) value :",php12)
def php2chf(l13):
  php13 = l13 * 0.018
  print("\nThe Swiss Franc (CHF) value :",php13)
def php2usd(l14):
  php14 = l14 * 0.019
  print("\nThe US Dollar (USD) value :",php14)
#SGD Conversion
def sgd2awg(m1):
  sgd1 = m1 * 1.31
  print("\nThe Aruban Florin (AWG) value :",sgd1)
def sgd2bgv(m2):
  sgd2 = m2 * 1.33
  print("\nThe Bulgarian Lev (BGV) value :",sgd2)
def sgd2cny(m3):
  sgd3 = m3 * 4.87
  print("\nThe Chinese Yuan (CNY) value :",sgd3)
def sgd2egp(m4):
  sgd4 = m4 * 13.53
  print("\nThe Egyptian Pound (EGP) value :",sgd4)
def sgd2eur(m5):
  sgd5 = m5 * 0.68
  print("\nThe Euro (EUR) value :",sgd5)
def sgd2inr(m6):
  sgd6 = m6 * 56.52
  print("\nThe Indian Rupee (INR) value :",sgd6)
def sgd2idr(m7):
  sgd7 = m7 * 10577.96
  print("\nThe Indonesian Rupiah (IDR) value :",sgd7)
def sgd2ils(m8):
  sgd8 = m8 * 2.43
  print("\nThe Israeli New Shekel (ILS) value :",sgd8)
def sgd2jpy(m9):
  sgd9 = m9 * 92.47
  print("\nThe Japanese Yen (JPY) value :",sgd9)
def sgd2kwd(m10):
  sgd10 = m10 * 0.22
  print("\nThe Kuwaiti Dinar (KWD) value :",sgd10)
def sgd2omr(m11):
  sgd11 = m11 * 0.28 
  print("\nThe Omani Rial (OMR) value :",sgd11)
def sgd2php(m12):
  sgd12 = m12 * 38.07
  print("\nThe Philippine Peso (PHP) value :",sgd12)
def sgd2chf(m13):
  sgd13 = m13 * 0.7
  print("\nThe Swiss Franc (CHF) value :",sgd13)
def sgd2usd(m14):
  sgd14 = m14 * 0.73
  print("\nThe US Dollar (USD) value :",sgd14)
#CHF Conversion
def chf2awg(n1):
  chf1 = n1 * 1.88
  print("\nThe Aruban Florin (AWG) value :",chf1)
def chf2bgv(n2):
  chf2 = n2 * 1.91
  print("\nThe Bulgarian Lev (BGV) value :",chf2)
def chf2cny(n3):
  chf3 = n3 * 7.00
  print("\nThe Chinese Yuan (CNY) value :",chf3)
def chf2egp(n4):
  chf4 = n4 * 19.42
  print("\nThe Egyptian Pound (EGP) value :",chf4)
def chf2eur(n5):
  chf5 = n5 * 0.97
  print("\nThe Euro (EUR) value :",chf5)
def chf2inr(n6):
  chf6 = n6 * 81.16
  print("\nThe Indian Rupee (INR) value :",chf6)
def chf2idr(n7):
  chf7 = n7 * 15187.71
  print("\nThe Indonesian Rupiah (IDR) value :",chf7)
def chf2ils(n8):
  chf8 = n8 * 3.49
  print("\nThe Israeli New Shekel (ILS) value :",chf8)
def chf2jpy(n9):
  chf9 = n9 * 132.76
  print("\nThe Japanese Yen (JPY) value :",chf9)
def chf2kwd(n10):
  chf10 = n10 * 0.32
  print("\nThe Kuwaiti Dinar (KWD) value :",chf10)
def chf2omr(n11):
  chf11 = n11 * 0.40 
  print("\nThe Omani Rial (OMR) value :",chf11)
def chf2php(n12):
  chf12 = n12 * 54.66
  print("\nThe Philippine Peso (PHP) value :",chf12)
def chf2sgd(n13):
  chf13 = n13 * 1.44
  print("\nThe Singapore Dollar (SGD) value :",chf13)
def chf2usd(n14):
  chf14 = n14 * 1.04
  print("\nThe US Dollar (USD) value :",chf14)
#uSD Conversion
def usd2awg(o1):
  usd1 = o1 * 1.80
  print("\nThe Aruban Florin (AWG) value :",usd1)
def usd2bgv(o2):
  usd2 = o2 * 1.83
  print("\nThe Bulgarian Lev (BGV) value :",usd2)
def usd2cny(o3):
  usd3 = o3 * 6.7
  print("\nThe Chinese Yuan (CNY) value :",usd3)
def usd2egp(o4):
  usd4 = o4 * 18.59
  print("\nThe Egyptian Pound (EGP) value :",usd4)
def usd2eur(o5):
  usd5 = o5 * 0.93
  print("\nThe Euro (EUR) value :",usd5)
def usd2inr(o6):
  usd6 = o6 * 77.69
  print("\nThe Indian Rupee (INR) value :",usd6)
def usd2idr(o7):
  usd7 = o7 * 14539.4
  print("\nThe Indonesian Rupiah (IDR) value :",usd7)
def usd2ils(o8):
  usd8 = o8 * 3.34
  print("\nThe Israeli New Shekel (ILS) value :",usd8)
def usd2jpy(o9):
  usd9 = o9 * 127.1
  print("\nThe Japanese Yen (JPY) value :",usd9)
def usd2kwd(o10):
  usd10 = o10 * 0.31
  print("\nThe Kuwaiti Dinar (KWD) value :",usd10)
def usd2omr(o11):
  usd11 = o11 * 0.39 
  print("\nThe Omani Rial (OMR) value :",usd11)
def usd2php(o12):
  usd12 = o12 * 52.32
  print("\nThe Philippine Peso (PHP) value :",usd12)
def usd2sgd(o13):
  usd13 = o13 * 1.37
  print("\nThe Singapore Dollar (SGD) value :",usd13)
def usd2chf(o14):
  usd14 = o14 * 0.96
  print("\nThe Swiss Franc (CHF) value :",usd14)
#Sub Function1 - for conversion
def awgconverter(awgc):
  print("\na)Aruban Florin (AWG) b)Bulgarian Lev (BGV) c)Chinese Yuan (CNY) d)Egyptian Pound (EGP) e)Euro (EUR) f)Indian Rupee (INR) g)Indonesian Rupiah (IDR) h)Israeli New Shekel (ILS) i)Japanese Yen (JPY) j)Kuwaiti Dinar (KWD) k)Omani Rial (OMR) l)Philippine Peso (PHP) m)Singapore Dollar (SGD) n)Swiss Franc (CHF) o)US Dollar (USD)")
  awgc1 = input(print("Choose the option - Currency convert to :"))
  if awgc1 == 'b':
    awg2bgv(val1)
  elif awgc1 == 'c':
    awg2cny(val1)
  elif awgc1 == 'd':
    awg2egp(val1)
  elif awgc1 == 'e':
    awg2eur(val1)
  elif awgc1 == 'f':
    awg2inr(val1)
  elif awgc1 == 'g':
    awg2idr(val1)
  elif awgc1 == 'h':
    awg2ils(val1)
  elif awgc1 == 'i':
    awg2jpy(val1)
  elif awgc1 == 'j':
    awg2kwd(val1)
  elif awgc1 == 'k':
    awg2omr(val1)
  elif awgc1 == 'l':
    awg2php(val1)
  elif awgc1 == 'm':
    awg2sgd(val1)
  elif awgc1 == 'n':
    awg2chf(val1)
  elif awgc1 == 'o':
    awg2usd(val1)
  else:
    print("\n Please choose the correct option")
def bgvconverter(bgvc):
  print("\na)Aruban Florin (AWG) b)Bulgarian Lev (BGV) c)Chinese Yuan (CNY) d)Egyptian Pound (EGP) e)Euro (EUR) f)Indian Rupee (INR) g)Indonesian Rupiah (IDR) h)Israeli New Shekel (ILS) i)Japanese Yen (JPY) j)Kuwaiti Dinar (KWD) k)Omani Rial (OMR) l)Philippine Peso (PHP) m)Singapore Dollar (SGD) n)Swiss Franc (CHF) o)US Dollar (USD)")
  bgvc1 = input(print("Choose the option - Currency convert to :"))
  if bgvc1 == 'a':
    bgv2awg(val2)
  elif bgvc1 == 'c':
    bgv2cny(val2)
  elif bgvc1 == 'd':
    bgv2egp(val2)
  elif bgvc1 == 'e':
    bgv2eur(val2)
  elif bgvc1 == 'f':
    bgv2inr(val2)
  elif bgvc1 == 'g':
    bgv2idr(val2)
  elif bgvc1 == 'h':
    bgv2ils(val2)
  elif bgvc1 == 'i':
    bgv2jpy(val2)
  elif bgvc1 == 'j':
    bgv2kwd(val2)
  elif bgvc1 == 'k':
    bgv2omr(val2)
  elif bgvc1 == 'l':
    bgv2php(val2)
  elif bgvc1 == 'm':
    bgv2sgd(val2)
  elif bgvc1 == 'n':
    bgv2chf(val2)
  elif bgvc1 == 'o':
    bgv2usd(val2)
  else:
    print("\n Please choose the correct option")
def cnyconverter(cnyc):
  print("\na)Aruban Florin (AWG) b)Bulgarian Lev (BGV) c)Chinese Yuan (CNY) d)Egyptian Pound (EGP) e)Euro (EUR) f)Indian Rupee (INR) g)Indonesian Rupiah (IDR) h)Israeli New Shekel (ILS) i)Japanese Yen (JPY) j)Kuwaiti Dinar (KWD) k)Omani Rial (OMR) l)Philippine Peso (PHP) m)Singapore Dollar (SGD) n)Swiss Franc (CHF) o)US Dollar (USD)")
  cnyc1 = input(print("Choose the option - Currency convert to :"))
  if cnyc1 == 'a':
    cny2awg(val3)
  elif cnyc1 == 'b':
    cny2bgv(val3)
  elif cnyc1 == 'd':
    cny2egp(val3)
  elif cnyc1 == 'e':
    cny2eur(val3)
  elif cnyc1 == 'f':
    cny2inr(val3)
  elif cnyc1 == 'g':
    cny2idr(val3)
  elif cnyc1 == 'h':
    cny2ils(val3)
  elif cnyc1 == 'i':
    cny2jpy(val3)
  elif cnyc1 == 'j':
    cny2kwd(val3)
  elif cnyc1 == 'k':
    cny2omr(val3)
  elif cnyc1 == 'l':
    cny2php(val3)
  elif cnyc1 == 'm':
    cny2sgd(val3)
  elif cnyc1 == 'n':
    cny2chf(val3)
  elif cnyc1 == 'o':
    cny2usd(val3)
  else:
    print("\n Please choose the correct option")
def egpconverter(egpc):
  print("\na)Aruban Florin (AWG) b)Bulgarian Lev (BGV) c)Chinese Yuan (CNY) d)Egyptian Pound (EGP) e)Euro (EUR) f)Indian Rupee (INR) g)Indonesian Rupiah (IDR) h)Israeli New Shekel (ILS) i)Japanese Yen (JPY) j)Kuwaiti Dinar (KWD) k)Omani Rial (OMR) l)Philippine Peso (PHP) m)Singapore Dollar (SGD) n)Swiss Franc (CHF) o)US Dollar (USD)")
  egpc1 = input(print("Choose the option - Currency convert to :"))
  if egpc1 == 'a':
    egp2awg(val4)
  elif egpc1 == 'b':
    egp2bgv(val4)
  elif egpc1 == 'c':
    egp2cny(val4)
  elif egpc1 == 'e':
    egp2eur(val4)
  elif egpc1 == 'f':
    egp2inr(val4)
  elif egpc1 == 'g':
    egp2idr(val4)
  elif egpc1 == 'h':
    egp2ils(val4)
  elif egpc1 == 'i':
    egp2jpy(val4)
  elif egpc1 == 'j':
    egp2kwd(val4)
  elif egpc1 == 'k':
    egp2omr(val4)
  elif egpc1 == 'l':
    egp2php(val4)
  elif egpc1 == 'm':
    egp2sgd(val4)
  elif egpc1 == 'n':
    egp2chf(val4)
  elif egpc1 == 'o':
    egp2usd(val4)
  else:
    print("\n Please choose the correct option")
def eurconverter(eurc):
  print("\na)Aruban Florin (AWG) b)Bulgarian Lev (BGV) c)Chinese Yuan (CNY) d)Egyptian Pound (EGP) e)Euro (EUR) f)Indian Rupee (INR) g)Indonesian Rupiah (IDR) h)Israeli New Shekel (ILS) i)Japanese Yen (JPY) j)Kuwaiti Dinar (KWD) k)Omani Rial (OMR) l)Philippine Peso (PHP) m)Singapore Dollar (SGD) n)Swiss Franc (CHF) o)US Dollar (USD)")
  eurc1 = input(print("Choose the option - Currency convert to :"))
  if eurc1 == 'a':
    eur2awg(val5)
  elif eurc1 == 'b':
    eur2bgv(val5)
  elif eurc1 == 'c':
    eur2cny(val5)
  elif eurc1 == 'd':
    eur2egp(val5)
  elif eurc1 == 'f':
    eur2inr(val5)
  elif eurc1 == 'g':
    eur2idr(val5)
  elif eurc1 == 'h':
    eur2ils(val5)
  elif eurc1 == 'i':
    eur2jpy(val5)
  elif eurc1 == 'j':
    eur2kwd(val5)
  elif eurc1 == 'k':
    eur2omr(val5)
  elif eurc1 == 'l':
    eur2php(val5)
  elif eurc1 == 'm':
    eur2sgd(val5)
  elif eurc1 == 'n':
    eur2chf(val5)
  elif eurc1 == 'o':
    eur2usd(val5)
  else:
    print("\n Please choose the correct option")
def inrconverter(inrc):
  print("\na)Aruban Florin (AWG) b)Bulgarian Lev (BGV) c)Chinese Yuan (CNY) d)Egyptian Pound (EGP) e)Euro (EUR) f)Indian Rupee (INR) g)Indonesian Rupiah (IDR) h)Israeli New Shekel (ILS) i)Japanese Yen (JPY) j)Kuwaiti Dinar (KWD) k)Omani Rial (OMR) l)Philippine Peso (PHP) m)Singapore Dollar (SGD) n)Swiss Franc (CHF) o)US Dollar (USD)")
  inrc1 = input(print("Choose the option - Currency convert to :"))
  if inrc1 == 'a':
    inr2awg(val6)
  elif inrc1 == 'b':
    inr2bgv(val6)
  elif inrc1 == 'c':
    inr2cny(val6)
  elif inrc1 == 'd':
    inr2egp(val6)
  elif inrc1 == 'e':
    inr2eur(val6)
  elif inrc1 == 'g':
    inr2idr(val6)
  elif inrc1 == 'h':
    inr2ils(val6)
  elif inrc1 == 'i':
    inr2jpy(val6)
  elif inrc1 == 'j':
    inr2kwd(val6)
  elif inrc1 == 'k':
    inr2omr(val6)
  elif inrc1 == 'l':
    inr2php(val6)
  elif inrc1 == 'm':
    inr2sgd(val6)
  elif inrc1 == 'n':
    inr2chf(val6)
  elif inrc1 == 'o':
    inr2usd(val6)
  else:
    print("\n Please choose the correct option")
def idrconverter(idrc):
  print("\na)Aruban Florin (AWG) b)Bulgarian Lev (BGV) c)Chinese Yuan (CNY) d)Egyptian Pound (EGP) e)Euro (EUR) f)Indian Rupee (INR) g)Indonesian Rupiah (IDR) h)Israeli New Shekel (ILS) i)Japanese Yen (JPY) j)Kuwaiti Dinar (KWD) k)Omani Rial (OMR) l)Philippine Peso (PHP) m)Singapore Dollar (SGD) n)Swiss Franc (CHF) o)US Dollar (USD)")
  idrc1 = input(print("Choose the option - Currency convert to :"))
  if idrc1 == 'a':
    idr2awg(val7)
  elif idrc1 == 'b':
    idr2bgv(val7)
  elif idrc1 == 'c':
    idr2cny(val7)
  elif idrc1 == 'd':
    idr2egp(val7)
  elif idrc1 == 'e':
    idr2eur(val7)
  elif idrc1 == 'f':
    idr2inr(val7)
  elif idrc1 == 'h':
    idr2ils(val7)
  elif idrc1 == 'i':
    idr2jpy(val7)
  elif idrc1 == 'j':
    idr2kwd(val7)
  elif idrc1 == 'k':
    idr2omr(val7)
  elif idrc1 == 'l':
    idr2php(val7)
  elif idrc1 == 'm':
    idr2sgd(val7)
  elif idrc1 == 'n':
    idr2chf(val7)
  elif idrc1 == 'o':
    idr2usd(val7)
  else:
    print("\n Please choose the correct option")
def ilsconverter(ilsc):
  print("\na)Aruban Florin (AWG) b)Bulgarian Lev (BGV) c)Chinese Yuan (CNY) d)Egyptian Pound (EGP) e)Euro (EUR) f)Indian Rupee (INR) g)Indonesian Rupiah (IDR) h)Israeli New Shekel (ILS) i)Japanese Yen (JPY) j)Kuwaiti Dinar (KWD) k)Omani Rial (OMR) l)Philippine Peso (PHP) m)Singapore Dollar (SGD) n)Swiss Franc (CHF) o)US Dollar (USD)")
  ilsc1 = input(print("Choose the option - Currency convert to :"))
  if ilsc1 == 'a':
    ils2awg(val8)
  elif ilsc1 == 'b':
    ils2bgv(val8)
  elif ilsc1 == 'c':
    ils2cny(val8)
  elif ilsc1 == 'd':
    ils2egp(val8)
  elif ilsc1 == 'e':
    ils2eur(val8)
  elif ilsc1 == 'f':
    ils2idr(val8)
  elif ilsc1 == 'g':
    ils2idr(val8)
  elif ilsc1 == 'i':
    ils2jpy(val8)
  elif ilsc1 == 'j':
    ils2kwd(val8)
  elif ilsc1 == 'k':
    ils2omr(val8)
  elif ilsc1 == 'l':
    ils2php(val8)
  elif ilsc1 == 'm':
    ils2sgd(val8)
  elif ilsc1 == 'n':
    ils2chf(val8)
  elif ilsc1 == 'o':
    ils2usd(val8)
  else:
    print("\n Please choose the correct option")
def jpyconverter(jpyc):
  print("\na)Aruban Florin (AWG) b)Bulgarian Lev (BGV) c)Chinese Yuan (CNY) d)Egyptian Pound (EGP) e)Euro (EUR) f)Indian Rupee (INR) g)Indonesian Rupiah (IDR) h)Israeli New Shekel (ILS) i)Japanese Yen (JPY) j)Kuwaiti Dinar (KWD) k)Omani Rial (OMR) l)Philippine Peso (PHP) m)Singapore Dollar (SGD) n)Swiss Franc (CHF) o)US Dollar (USD)")
  jpyc1 = input(print("Choose the option - Currency convert to :"))
  if jpyc1 == 'a':
    jpy2awg(val9)
  elif jpyc1 == 'b':
    jpy2bgv(val9)
  elif jpyc1 == 'c':
    jpy2cny(val9)
  elif jpyc1 == 'd':
    jpy2egp(val9)
  elif jpyc1 == 'e':
    jpy2eur(val9)
  elif jpyc1 == 'f':
    jpy2idr(val9)
  elif jpyc1 == 'g':
    jpy2idr(val9)
  elif jpyc1 == 'h':
    jpy2ils(val9)
  elif jpyc1 == 'j':
    jpy2kwd(val9)
  elif jpyc1 == 'k':
    jpy2omr(val9)
  elif jpyc1 == 'l':
    jpy2php(val9)
  elif jpyc1 == 'm':
    jpy2sgd(val9)
  elif jpyc1 == 'n':
    jpy2chf(val9)
  elif jpyc1 == 'o':
    jpy2usd(val9)
  else:
    print("\n Please choose the correct option")
def kwdconverter(kwdc):
  print("\na)Aruban Florin (AWG) b)Bulgarian Lev (BGV) c)Chinese Yuan (CNY) d)Egyptian Pound (EGP) e)Euro (EUR) f)Indian Rupee (INR) g)Indonesian Rupiah (IDR) h)Israeli New Shekel (ILS) i)Japanese Yen (JPY) j)Kuwaiti Dinar (KWD) k)Omani Rial (OMR) l)Philippine Peso (PHP) m)Singapore Dollar (SGD) n)Swiss Franc (CHF) o)US Dollar (USD)")
  kwdc1 = input(print("Choose the option - Currency convert to :"))
  if kwdc1 == 'a':
    kwd2awg(val10)
  elif kwdc1 == 'b':
    kwd2bgv(val10)
  elif kwdc1 == 'c':
    kwd2cny(val10)
  elif kwdc1 == 'd':
    kwd2egp(val10)
  elif kwdc1 == 'e':
    kwd2eur(val10)
  elif kwdc1 == 'f':
    kwd2idr(val10)
  elif kwdc1 == 'g':
    kwd2idr(val10)
  elif kwdc1 == 'h':
    kwd2ils(val10)
  elif kwdc1 == 'i':
    kwd2jpy(val10)
  elif kwdc1 == 'j':
    kwd2omr(val10)
  elif kwdc1 == 'l':
    kwd2php(val10)
  elif kwdc1 == 'm':
    kwd2sgd(val10)
  elif kwdc1 == 'n':
    kwd2chf(val10)
  elif kwdc1 == 'o':
    kwd2usd(val10)
  else:
    print("\n Please choose the correct option")
def omrconverter(omrc):
  print("\na)Aruban Florin (AWG) b)Bulgarian Lev (BGV) c)Chinese Yuan (CNY) d)Egyptian Pound (EGP) e)Euro (EUR) f)Indian Rupee (INR) g)Indonesian Rupiah (IDR) h)Israeli New Shekel (ILS) i)Japanese Yen (JPY) j)Kuwaiti Dinar (KWD) k)Omani Rial (OMR) l)Philippine Peso (PHP) m)Singapore Dollar (SGD) n)Swiss Franc (CHF) o)US Dollar (USD)")
  omrc1 = input(print("Choose the option - Currency convert to :"))
  if omrc1 == 'a':
    omr2awg(val11)
  elif omrc1 == 'b':
    omr2bgv(val11)
  elif omrc1 == 'c':
    omr2cny(val11)
  elif omrc1 == 'd':
    omr2egp(val11)
  elif omrc1 == 'e':
    omr2eur(val11)
  elif omrc1 == 'f':
    omr2idr(val11)
  elif omrc1 == 'g':
    omr2idr(val11)
  elif omrc1 == 'h':
    omr2ils(val11)
  elif omrc1 == 'i':
    omr2jpy(val11)
  elif omrc1 == 'j':
    omr2kwd(val11)
  elif omrc1 == 'l':
    omr2php(val11)
  elif omrc1 == 'm':
    omr2sgd(val11)
  elif omrc1 == 'n':
    omr2chf(val11)
  elif omrc1 == 'o':
    omr2usd(val11)
  else:
    print("\n Please choose the correct option")
def phpconverter(phpc):
  print("\na)Aruban Florin (AWG) b)Bulgarian Lev (BGV) c)Chinese Yuan (CNY) d)Egyptian Pound (EGP) e)Euro (EUR) f)Indian Rupee (INR) g)Indonesian Rupiah (IDR) h)Israeli New Shekel (ILS) i)Japanese Yen (JPY) j)Kuwaiti Dinar (KWD) k)Omani Rial (OMR) l)Philippine Peso (PHP) m)Singapore Dollar (SGD) n)Swiss Franc (CHF) o)US Dollar (USD)")
  phpc1 = input(print("Choose the option - Currency convert to :"))
  if phpc1 == 'a':
    php2awg(val12)
  elif phpc1 == 'b':
    php2bgv(val12)
  elif phpc1 == 'c':
    php2cny(val12)
  elif phpc1 == 'd':
    php2egp(val12)
  elif phpc1 == 'e':
    php2eur(val12)
  elif phpc1 == 'f':
    php2idr(val12)
  elif phpc1 == 'g':
    php2idr(val12)
  elif phpc1 == 'h':
    php2ils(val12)
  elif phpc1 == 'i':
    php2jpy(val12)
  elif phpc1 == 'j':
    php2kwd(val12)
  elif phpc1 == 'k':
    php2omr(val12)
  elif phpc1 == 'm':
    php2sgd(val12)
  elif phpc1 == 'n':
    php2chf(val12)
  elif phpc1 == 'o':
    php2usd(val12)
  else:
    print("\n Please choose the correct option")
def sgdconverter(sgdc):
  print("\na)Aruban Florin (AWG) b)Bulgarian Lev (BGV) c)Chinese Yuan (CNY) d)Egyptian Pound (EGP) e)Euro (EUR) f)Indian Rupee (INR) g)Indonesian Rupiah (IDR) h)Israeli New Shekel (ILS) i)Japanese Yen (JPY) j)Kuwaiti Dinar (KWD) k)Omani Rial (OMR) l)Philippine Peso (PHP) m)Singapore Dollar (SGD) n)Swiss Franc (CHF) o)US Dollar (USD)")
  sgdc1 = input(print("Choose the option - Currency convert to :"))
  if sgdc1 == 'a':
    sgd2awg(val13)
  elif sgdc1 == 'b':
    php2bgv(val13)
  elif sgdc1 == 'c':
    sgd2cny(val13)
  elif sgdc1 == 'd':
    sgd2egp(val13)
  elif sgdc1 == 'e':
    sgd2eur(val13)
  elif sgdc1 == 'f':
    sgd2idr(val13)
  elif sgdc1 == 'g':
    sgd2idr(val13)
  elif sgdc1 == 'h':
    sgd2ils(val13)
  elif sgdc1 == 'i':
    sgd2jpy(val13)
  elif sgdc1 == 'j':
    sgd2kwd(val13)
  elif sgdc1 == 'k':
    sgd2omr(val13)
  elif sgdc1 == 'l':
    sgd2php(val13)
  elif sgdc1 == 'n':
    sgd2chf(val13)
  elif sgdc1 == 'o':
    sgd2usd(val13)
  else:
    print("\n Please choose the correct option")
def chfconverter(chfc):
  print("\na)Aruban Florin (AWG) b)Bulgarian Lev (BGV) c)Chinese Yuan (CNY) d)Egyptian Pound (EGP) e)Euro (EUR) f)Indian Rupee (INR) g)Indonesian Rupiah (IDR) h)Israeli New Shekel (ILS) i)Japanese Yen (JPY) j)Kuwaiti Dinar (KWD) k)Omani Rial (OMR) l)Philippine Peso (PHP) m)Singapore Dollar (SGD) n)Swiss Franc (CHF) o)US Dollar (USD)")
  chfc1 = input(print("Choose the option - Currency convert to :"))
  if chfc1 == 'a':
    chf2awg(val14)
  elif chfc1 == 'b':
    chf2bgv(val14)
  elif chfc1 == 'c':
    chf2cny(val14)
  elif chfc1 == 'd':
    chf2egp(val14)
  elif chfc1 == 'e':
    chf2eur(val14)
  elif chfc1 == 'f':
    chf2idr(val14)
  elif chfc1 == 'g':
    chf2idr(val14)
  elif chfc1 == 'h':
    chf2ils(val14)
  elif chfc1 == 'i':
    chf2jpy(val14)
  elif chfc1 == 'j':
    chf2kwd(val14)
  elif chfc1 == 'k':
    chf2omr(val14)
  elif chfc1 == 'l':
    chf2php(val14)
  elif chfc1 == 'm':
    chf2sgd(val14)
  elif chfc1 == 'o':
    chf2usd(val14)
  else:
    print("\n Please choose the correct option")
def usdconverter(usdc):
  print("\na)Aruban Florin (AWG) b)Bulgarian Lev (BGV) c)Chinese Yuan (CNY) d)Egyptian Pound (EGP) e)Euro (EUR) f)Indian Rupee (INR) g)Indonesian Rupiah (IDR) h)Israeli New Shekel (ILS) i)Japanese Yen (JPY) j)Kuwaiti Dinar (KWD) k)Omani Rial (OMR) l)Philippine Peso (PHP) m)Singapore Dollar (SGD) n)Swiss Franc (CHF) o)US Dollar (USD)")
  usdc1 = input(print("Choose the option - Currency convert to :"))
  if usdc1 == 'a':
    usd2awg(val15)
  elif usdc1 == 'b':
    usd2bgv(val15)
  elif usdc1 == 'c':
    usd2cny(val15)
  elif usdc1 == 'd':
    usd2egp(val15)
  elif usdc1 == 'e':
    usd2eur(val15)
  elif usdc1 == 'f':
    usd2idr(val15)
  elif usdc1 == 'g':
    usd2idr(val15)
  elif usdc1 == 'h':
    usd2ils(val15)
  elif usdc1 == 'i':
    usd2jpy(val15)
  elif usdc1 == 'j':
    usd2kwd(val15)
  elif usdc1 == 'k':
    usd2omr(val15)
  elif usdc1 == 'l':
    usd2php(val15)
  elif usdc1 == 'm':
    usd2sgd(val15)
  elif usdc1 == 'n':
    usd2chf(val15)
  else:
    print("\n Please choose the correct option")
#Main Function
print("\nCAPSTONE PROJECT - 2")
print("\nHI, WELCOME TO CURRENCY CONVERTER !!")
print("\na)Aruban Florin (AWG) b)Bulgarian Lev (BGV) c)Chinese Yuan (CNY) d)Egyptian Pound (EGP) e)Euro (EUR) f)Indian Rupee (INR) g)Indonesian Rupiah (IDR) \nh)Israeli New Shekel (ILS) i)Japanese Yen (JPY) j)Kuwaiti Dinar (KWD) k)Omani Rial (OMR) l)Philippine Peso (PHP) m)Singapore Dollar (SGD) n)Swiss Franc (CHF) o)US Dollar (USD)")
op1 = input(print("\nChoose the option - Currency convertion from :"))
if op1 == 'a':
  val1 = float(input(print("\n Enter the Aruban Florin (AWG) value :")))
  awgconverter(val1) 
elif op1 == 'b':
  val2 = float(input(print("\n Enter the Bulgarian Lev (BGV) value :")))
  bgvconverter(val2)
elif op1 == 'c':
  val3 = float(input(print("\n Enter the Chinese Yuan (CNY) value :")))
  cnyconverter(val3)
elif op1 == 'd':
  val4 = float(input(print("\n Enter the Egyptian Pound (EGP) value :")))
  egpconverter(val4)
elif op1 == 'e':
  val5 = float(input(print("\n Enter the Euro (EUR) value :")))
  eurconverter(val5)
elif op1 == 'f':
  val6 = float(input(print("\n Enter the Indian Rupee (INR) value :")))
  inrconverter(val6)
elif op1 == 'g':
  val7 = float(input(print("\n Enter the Indonesian Rupiah (IDR) value :")))
  idrconverter(val7)
elif op1 == 'h':
  val8 = float(input(print("\n Enter the Israeli New Shekel (ILS) value :")))
  ilsconverter(val8)
elif op1 == 'i':
  val9 = float(input(print("\n Enter the Japanese Yen (JPY) value :")))
  jpyconverter(val9)
elif op1 == 'j':
  val10 = float(input(print("\n Enter the Kuwaiti Dinar (KWD) value :")))
  kwdconverter(val10)
elif op1 == 'k':
  val11 = float(input(print("\n Enter the Omani Rial (OMR) value :")))
  omrconverter(val11)
elif op1 == 'l':
  val12 = float(input(print("\n Enter the Philippine Peso (PHP) value :")))
  phpconverter(val12)
elif op1 == 'm':
  val13 = float(input(print("\n Enter the Singapore Dollar (SGD) value :")))
  sgdconverter(val13)
elif op1 == 'n':
  val14 = float(input(print("\n Enter the Swiss Franc (CHF) value :")))
  chfconverter(val14)
elif op1 == 'o':
  val15 = float(input(print("\n Enter the US Dollar (USD) value :")))
  usdconverter(val15)
else:
    print("\n Please choose the correct option")
# Out:
# CAPSTONE PROJECT - 2
#
# HI, WELCOME TO CURRENCY CONVERTER !!
#
# a)Aruban Florin (AWG) b)Bulgarian Lev (BGV) c)Chinese Yuan (CNY) d)Egyptian Pound (EGP) e)Euro (EUR) f)Indian Rupee (INR) g)Indonesian Rupiah (IDR)
# h)Israeli New Shekel (ILS) i)Japanese Yen (JPY) j)Kuwaiti Dinar (KWD) k)Omani Rial (OMR) l)Philippine Peso (PHP) m)Singapore Dollar (SGD) n)Swiss Franc (CHF) o)US Dollar (USD)
#
# Choose the option - Currency convertion from :
# a
#
#  Enter the Aruban Florin (AWG) value :
# 43
#
# a)Aruban Florin (AWG) b)Bulgarian Lev (BGV) c)Chinese Yuan (CNY) d)Egyptian Pound (EGP) e)Euro (EUR) f)Indian Rupee (INR) g)Indonesian Rupiah (IDR) h)Israeli New Shekel (ILS) i)Japanese Yen (JPY) j)Kuwaiti Dinar (KWD) k)Omani Rial (OMR) l)Philippine Peso (PHP) m)Singapore Dollar (SGD) n)Swiss Franc (CHF) o)US Dollar (USD)
# Choose the option - Currency convert to :
# b
#
# The Bulgarian Lev (BGV) value : 43.43
